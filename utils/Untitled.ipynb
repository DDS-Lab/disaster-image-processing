# %%
import geopandas as gpd
import sys

# %%
input_geo = gpd.read_file('/Users/Chris/Desktop/Hey/dssg/digitalglobe_crowdsourcing_hurricane_harvey_20170915/DG_bfp.shp')

# %%
boundinggeo = input_geo.copy()

# %%
print(boundinggeo)
# Out:
#         OBJECTID BUILDING_I OCC_TYPE MOBILEHOME OUTBLDG HEIGHT   SQUAREMETE  \
# 0      1969534.0    1969534     None       None    None   None   761.406616
# 1      1903876.0    1903876     None       None    None   None   159.657623
# 2      1969535.0    1969535     None       None    None   None   210.043625
# 3      3251676.0    3251676     None       None    None   None    65.562103
# 4      1111828.0    1111828     None       None    None   None   230.287537
# 5      1903883.0    1903883     None       None    None   None   132.673370
# 6      3251682.0    3251682     None       None    None   None    39.486855
# 7      1903884.0    1903884     None       None    None   None    53.219082
# 8      1111833.0    1111833     None       None    None   None   225.698456
# 9      2035210.0    2035210     None       None    None   None   140.118271
# 10     3251688.0    3251688     None       None    None   None   201.160278
# ...
